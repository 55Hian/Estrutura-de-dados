# %% [markdown]
# #### 1) Este exercício envolve a implementação dos métodos **insert_element**, **remove_element**, **search_element** e **reverse_array** na classe **ArrayManipulator**. Encorajo você a preencher o código desses métodos para realizar as operações correspondentes nos arrays.

# %%
class ArrayManipulator:
    def __init__(self, array):
        self.array = array
        self.arrayTemp = []
        self.capacidade = len(array) - 1

    def get_array(self):
        return self.array

    def insert_element(self, index, element):
        """
        Insere um elemento na posição especificada do array.

        Parameters:
        - index (int): Índice onde o elemento será inserido.
        - element: Elemento a ser inserido.

        Retorna:
        - True se a inserção for bem-sucedida, False caso contrário.
        """
        # Implemente o código aqui]
                        
        for i in range(self.capacidade):
            if i == index:
                if self.capacidade == len(self.array) - 1:
                    print('Capacidade máxima atingida, não foi possível inserir um novo valor')
                    return False
                else:
                    for j in range(self.capacidade, index, -1): 
                        self.array[j] = self.array[j-1]
                    self.array[index] = element
                    self.capacidade += 1
                    return True

    def remove_element(self, element):
        """
        Remove a primeira ocorrência do elemento no array.

        Parameters:
        - element: Elemento a ser removido.

        Retorna:
        - True se a remoção for bem-sucedida, False caso contrário.
        """
        # Implemente o código aqui

        posicao = self.search_element(element)
        if posicao == -1:
            return False
        else:
            for i in range(posicao, self.capacidade):
                self.array[i] = self.array[i+1]

            self.capacidade -= 1
            return True

    def search_element(self, element):
        """
        Procura a primeira ocorrência do elemento no array.

        Parameters:
        - element: Elemento a ser procurado.

        Retorna:
        - O índice do elemento se encontrado, ou -1 caso contrário.
        """
        # Implemente o código aqui

        for i in range(self.capacidade):
            if element == self.array[i]:
                return i
        return -1
    

    def reverse_array(self):
        """
        Inverte a ordem dos elementos no array.

        Retorna:
        - O array invertido.
        """
        # Implemente o código aqui

        for i in range(self.capacidade, -1, -1):
            self.arrayTemp.append(self.array[i])
        self.array = self.arrayTemp
        return self.array
# Exemplo de uso:
array_exemplo = [1, 2, 3, 4, 5]
manipulador = ArrayManipulator(array_exemplo)

# Teste dos métodos
print("Array original:", manipulador.get_array())


# Insira um elemento na posição 2
manipulador.insert_element(2, 10)
print("Array após inserção:", manipulador.get_array())

# Remova o elemento 4
manipulador.remove_element(4)
print("Array após remoção:", manipulador.get_array())

# Insira um elemento na posição 2
manipulador.insert_element(2, 10)
print("Array após inserção:", manipulador.get_array())

# Procure o elemento 3
indice = manipulador.search_element(3)
print("Índice do elemento 3:", indice)

# Inverta o array
array_invertido = manipulador.reverse_array()
print("Array invertido:", array_invertido)
# Out:
# Array original: [1, 2, 3, 4, 5]
# Capacidade máxima atingida, não foi possível inserir um novo valor
# Array após inserção: [1, 2, 3, 4, 5]
# Array após remoção: [1, 2, 3, 5, 5]
# Array após inserção: [1, 2, 10, 3, 5]
# Índice do elemento 3: 3
# Array invertido: [5, 3, 10, 2, 1]

# %% [markdown]
# ##### Depois de sua implementação e testes, explique aqui, detalhadamente, o que faz o algoritmo acima:
#
# - É declarada uma classe de nome "ArrayManipulator"
# - Definimos o construtor da classe, é onde atribuimos os atributos da classe
#
# <center>
#
# ![image-2.png](attachment:image-2.png)
#
# </center>
#
# - Temos algumas funções no codigo:
#
#     1) A função "get_array", não recebe parametros, é responsavel por apresentar a array sempre que chamada.
#
#     2) A função "insert_element", recebe os parametros "index" e "element", é responsavel por inserir um valor("element") na posição recebida no parametro("index").
#
#         - Perocorremos o array em busca do index passado
#
#             - Ao encontrar o index, verificamos se existe espaço disponivel na array, caso não tenha espaço,enviaremos uma mensagem indicando a falta de espaço na array e retornaremos o valor false.
#
#             - Se houver espaço disponivel, mudaremos a posição dos valores existentes após o index na array utilizando um laço for, e então, armazenaremos o valor "element" na posição "index", atualizamos a capacidade e retornaremos o valor True.
#
#     3) A função "remove_element", recebe o parametro "element", é responsavel por remover o valor passado pelo parametro "element" na array.
#
#         - O primeiro passo a ser executado é verificar qual o indice do elemento  a ser removido, utilizamos a função "search_element()" para executar essa tarefa.
#
#             - caso o valor retornado pela função seja -1, retornamos false.
#
#             - caso o valor retornado pela função seja o indice do elemento, percorremos a array entre o indice do elemento a ser removido e o fim da array, durante os ciclos, substituimos o valor do indice pelo valor do (indice + 1), sobrepondo assim, o valor que precisou ser excluido. Ao fim do processo, atualizamos a capacidade e retornamos True.
#
#     4) A função "search_element", recebe o parametro "element", é responsavel por buscar o indice do valor passado pelo parametro "element" na array.
#
#         - Perocorremos o array em busca do valor passado.
#
#             - se o valor for encontrado, retornamos o indice desse valor.
#
#             - se o valor não for encontrado, retornamos o valor -1.
#
#     5) A função "reverse_array", não recebe parametros, é responsavel por inverter o valores da array.
#
#         - Percorremos a array do maior valor para  o menor valor utilizando o "fpr - in", a cada ciclo, adicionamos o valor do indice atual encontrado na array "arrayTemp". Quando o loop finaliza, temos os valores de "array" em "arrayTemp", mas "arrayTemp" será inversa a "array" devido a forma de incremento decrescente que foi utilizada.
#
#         - Armazenamos "arrayTemp" em "array".
#
#         - Retornamos array.

# %% [markdown]
# #### 2) Neste exercício, você deve implementar os métodos is_empty, append, prepend, delete e display na classe LinkedList. Esses métodos devem realizar operações típicas em listas ligadas, como verificar se está vazia, adicionar elementos no final ou no início, remover um elemento específico e exibir os elementos da lista. Encorajo você a preencher o código desses métodos para completar as operações na lista ligada.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next_node = None

class LinkedList:
    def __init__(self):
        self.head = None

    def is_empty(self):
        """
        Verifica se a lista está vazia.

        Retorna:
        - True se a lista estiver vazia, False caso contrário.
        """
        # Implemente o código aqui
        pass

    def append(self, data):
        """
        Adiciona um novo nó ao final da lista.

        Parameters:
        - data: Dado a ser armazenado no novo nó.

        Retorna:
        - Nenhum retorno.
        """
        # Implemente o código aqui
        pass

    def prepend(self, data):
        """
        Adiciona um novo nó no início da lista.

        Parameters:
        - data: Dado a ser armazenado no novo nó.

        Retorna:
        - Nenhum retorno.
        """
        # Implemente o código aqui
        pass

    def delete(self, data):
        """
        Remove o primeiro nó que contém o dado especificado.

        Parameters:
        - data: Dado a ser removido.

        Retorna:
        - True se a remoção for bem-sucedida, False caso contrário.
        """
        # Implemente o código aqui
        pass

    def display(self):
        """
        Exibe os elementos da lista.

        Retorna:
        - Uma representação da lista.
        """
        # Implemente o código aqui
        pass

# Exemplo de uso:
linked_list = LinkedList()

# Teste dos métodos
print("Lista vazia:", linked_list.is_empty())

# Adicione elementos ao final da lista
linked_list.append(1)
linked_list.append(2)
linked_list.append(3)

# Adicione elementos no início da lista
linked_list.prepend(0)
linked_list.prepend(-1)

print("Lista após adição:", linked_list.display())

# Remova um elemento
linked_list.delete(2)
print("Lista após remoção:", linked_list.display())

# %% [markdown]
# #Depois de sua implementação e testes, explique aqui, detalhadamente, o que faz o algoritmo acima:

# %% [markdown]
# #### 3) Neste exercício, assim como nos exemplos anteriores, você deve implementar os métodos **is_empty**, **append**, **prepend**, **delete** e **display** na classe **CircularLinkedList**. Estes métodos devem realizar operações típicas em listas ligadas circulares, como verificar se está vazia, adicionar elementos no final ou no início, remover um elemento específico e exibir os elementos da lista. Encorajo você a preencher o código desses métodos para completar as operações na lista ligada circular.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next_node = None

class CircularLinkedList:
    def __init__(self):
        self.head = None

    def is_empty(self):
        """
        Verifica se a lista está vazia.

        Retorna:
        - True se a lista estiver vazia, False caso contrário.
        """
        # Implemente o código aqui
        pass

    def append(self, data):
        """
        Adiciona um novo nó ao final da lista.

        Parameters:
        - data: Dado a ser armazenado no novo nó.

        Retorna:
        - Nenhum retorno.
        """
        # Implemente o código aqui
        pass

    def prepend(self, data):
        """
        Adiciona um novo nó no início da lista.

        Parameters:
        - data: Dado a ser armazenado no novo nó.

        Retorna:
        - Nenhum retorno.
        """
        # Implemente o código aqui
        pass

    def delete(self, data):
        """
        Remove o primeiro nó que contém o dado especificado.

        Parameters:
        - data: Dado a ser removido.

        Retorna:
        - True se a remoção for bem-sucedida, False caso contrário.
        """
        # Implemente o código aqui
        pass

    def display(self):
        """
        Exibe os elementos da lista.

        Retorna:
        - Uma representação da lista.
        """
        # Implemente o código aqui
        pass

# Exemplo de uso:
circular_linked_list = CircularLinkedList()

# Teste dos métodos
print("Lista vazia:", circular_linked_list.is_empty())

# Adicione elementos ao final da lista
circular_linked_list.append(1)
circular_linked_list.append(2)
circular_linked_list.append(3)

# Adicione elementos no início da lista
circular_linked_list.prepend(0)
circular_linked_list.prepend(-1)

print("Lista após adição:", circular_linked_list.display())

# Remova um elemento
circular_linked_list.delete(2)
print("Lista após remoção:", circular_linked_list.display())

# %% [markdown]
# #Depois de sua implementação e testes, explique aqui, detalhadamente, o que faz o algoritmo acima:

# %% [markdown]
# #### 4) Neste exercício, como nos exemplos anteriores, você deve implementar os métodos **is_empty**, **append**, **prepend**, **delete** e **display** na classe **DoublyLinkedList**. Esses métodos devem realizar operações típicas em listas duplamente ligadas, como verificar se está vazia, adicionar elementos no final ou no início, remover um elemento específico e exibir os elementos da lista. Encorajo você a preencher o código desses métodos para completar as operações na lista duplamente ligada.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next_node = None
        self.prev_node = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def is_empty(self):
        """
        Verifica se a lista está vazia.

        Retorna:
        - True se a lista estiver vazia, False caso contrário.
        """
        # Implemente o código aqui
        pass

    def append(self, data):
        """
        Adiciona um novo nó ao final da lista.

        Parameters:
        - data: Dado a ser armazenado no novo nó.

        Retorna:
        - Nenhum retorno.
        """
        # Implemente o código aqui
        pass

    def prepend(self, data):
        """
        Adiciona um novo nó no início da lista.

        Parameters:
        - data: Dado a ser armazenado no novo nó.

        Retorna:
        - Nenhum retorno.
        """
        # Implemente o código aqui
        pass

    def delete(self, data):
        """
        Remove o primeiro nó que contém o dado especificado.

        Parameters:
        - data: Dado a ser removido.

        Retorna:
        - True se a remoção for bem-sucedida, False caso contrário.
        """
        # Implemente o código aqui
        pass

    def display(self):
        """
        Exibe os elementos da lista.

        Retorna:
        - Uma representação da lista.
        """
        # Implemente o código aqui
        pass

# Exemplo de uso:
doubly_linked_list = DoublyLinkedList()

# Teste dos métodos
print("Lista vazia:", doubly_linked_list.is_empty())

# Adicione elementos ao final da lista
doubly_linked_list.append(1)
doubly_linked_list.append(2)
doubly_linked_list.append(3)

# Adicione elementos no início da lista
doubly_linked_list.prepend(0)
doubly_linked_list.prepend(-1)

print("Lista após adição:", doubly_linked_list.display())

# Remova um elemento
doubly_linked_list.delete(2)
print("Lista após remoção:", doubly_linked_list.display())

# %% [markdown]
# #Depois de sua implementação e testes, explique aqui, detalhadamente, o que faz o algoritmo acima:

# %% [markdown]
# #### 5) Um exemplo do mundo real que pode ser representado eficientemente por uma estrutura de dados ligada é uma lista de reprodução de músicas em um aplicativo de música. Crie as classes Musica e PlayList de forma que o código seja capaz de:
#
#
#
# 1.   Adicionar artista e músicas à lista de reprodução;
# 2.   reproduzir a play list.

# %%
#Escreva seu código aqui!

# %% [markdown]
# #Depois de sua implementação e testes, explique aqui, detalhadamente, o que faz o algoritmo acima:
